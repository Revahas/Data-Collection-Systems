# %%
from seleniumbase import Driver
from selenium.webdriver.common.by import By
import time
import csv
import pandas as pd

# Function to collect match data for a given league URL
def collect_league_data(base_url, league_code, valid_seasons, output_file):
    all_dates_list = []
    all_homeTeams_list = []
    all_awayTeams_list = []
    all_scores_list = []
    league_played_list = []

    for season in valid_seasons:
        full_url = f"{base_url}/{league_code}-{season}"

        # Navigate to the URL
        driver.get(full_url)
        # Wait to ensure the page loads completely
        time.sleep(3)

        # Extract match data
        match_dates = driver.find_elements(By.XPATH, '//*[@class="standard_tabelle"]/tbody/tr[*]/td[1]')
        match_homeTeams = driver.find_elements(By.XPATH, '//*[@class="standard_tabelle"]/tbody/tr[*]/td[3]')
        match_awayTeams = driver.find_elements(By.XPATH, '//*[@class="standard_tabelle"]/tbody/tr[*]/td[5]')
        match_scores = driver.find_elements(By.XPATH, '//*[@class="standard_tabelle"]/tbody/tr[*]/td[6]')

        # Append data to the lists
        all_dates_list.extend([date.text for date in match_dates])
        all_homeTeams_list.extend([team.text for team in match_homeTeams])
        all_awayTeams_list.extend([team.text for team in match_awayTeams])
        all_scores_list.extend([score.text for score in match_scores])
        league_played_list.extend([season] * len(match_dates))

    # Ensure all lists have the same length
    min_length = min(len(all_dates_list), len(all_homeTeams_list), len(all_awayTeams_list), len(all_scores_list), len(league_played_list))

    # Save the data to a CSV file
    with open(output_file, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(["Date", "Home Team", "Away Team", "Score", "Season"])
        for i in range(min_length):
            writer.writerow([all_dates_list[i], all_homeTeams_list[i], all_awayTeams_list[i], all_scores_list[i], league_played_list[i]])

    # Create the data dictionary with the first 20 elements of each list
    data = {
        "Dates": all_dates_list[:20],
        "Home Team": all_homeTeams_list[:20],
        "Away Team": all_awayTeams_list[:20],
        "Score": all_scores_list[:20],
        "League Played": league_played_list[:20]
    }

    df = pd.DataFrame(data)

    print(df)

# Initialize the driver
driver = Driver(uc=True)

try:
    # Define base URLs and league codes
    leagues = {
        "Turkey": "https://www.worldfootball.net/all_matches/tur-sueperlig",
        "France": "https://www.worldfootball.net/all_matches/fra-ligue-1",
        "England": "https://www.worldfootball.net/all_matches/eng-premier-league",
        "Spain": "https://www.worldfootball.net/all_matches/esp-primera-division",
        "Germany": "https://www.worldfootball.net/all_matches/bundesliga",
    }

    # Define valid seasons
    valid_seasons = [f"{year}-{year + 1}" for year in range(2000, 2025)]

    # Collect data for each league and save to separate CSV files
    for league_name, base_url in leagues.items():
        print(f"Processing league: {league_name}")
        output_file = f"{league_name}_matches.csv"
        collect_league_data(base_url, base_url.split('/')[-1], valid_seasons, output_file)

finally:
    driver.quit()

print("Data collection completed. CSV files saved.")
# Out:
# Processing league: Turkey
#          Dates            Home Team            Away Team      Score  \
# 0   05/08/2022      İstanbulspor AŞ          Trabzonspor  0:2 (0:1)
# 1   06/08/2022            Sivasspor         Gaziantep FK  1:1 (0:1)
# 2                          Beşiktaş          Kayserispor  1:0 (0:0)
# 3   07/08/2022          Giresunspor      Adana Demirspor  2:3 (0:2)
# 4                  Fatih Karagümrük           Alanyaspor  2:4 (0:2)
# 5                       Antalyaspor          Galatasaray  0:1 (0:0)
# 6   08/08/2022  İstanbul Başakşehir         Kasımpaşa SK  4:0 (2:0)
# 7                    MKE Ankaragücü            Konyaspor  0:0 (0:0)
# 8                        Fenerbahçe         Ümraniyespor  3:3 (2:1)
# 9   12/08/2022          Trabzonspor            Hatayspor  1:0 (0:0)
# 10  13/08/2022          Kayserispor      İstanbulspor AŞ  1:0 (1:0)
# 11                  Adana Demirspor            Sivasspor  3:0 (1:0)
# 12                      Galatasaray          Giresunspor  0:1 (0:0)
# 13  14/08/2022         Gaziantep FK       MKE Ankaragücü  1:0 (0:0)
# 14                     Ümraniyespor          Antalyaspor  0:1 (0:0)
# 15                       Alanyaspor             Beşiktaş  3:3 (1:3)
# 16  15/08/2022            Konyaspor  İstanbul Başakşehir  0:0 (0:0)
# 17                     Kasımpaşa SK           Fenerbahçe  0:6 (0:3)
# 18  19/08/2022         Ümraniyespor          Galatasaray  0:1 (0:0)
# 19  20/08/2022          Giresunspor         Kasımpaşa SK  1:0 (0:0)
#
#    League Played
# 0      2022-2023
# 1      2022-2023
# 2      2022-2023
# 3      2022-2023
# 4      2022-2023
# 5      2022-2023
# 6      2022-2023
# 7      2022-2023
# 8      2022-2023
# 9      2022-2023
# 10     2022-2023
# 11     2022-2023
# 12     2022-2023
# 13     2022-2023
# 14     2022-2023
# 15     2022-2023
# 16     2022-2023
# 17     2022-2023
# 18     2022-2023
# 19     2022-2023
# Processing league: France
#          Dates            Home Team            Away Team      Score  \
# 0   05/08/2022   Olympique Lyonnais           AC Ajaccio  2:1 (2:1)
# 1   06/08/2022        RC Strasbourg            AS Monaco  1:2 (0:1)
# 2                  Clermont Foot 63  Paris Saint-Germain  0:5 (0:3)
# 3   07/08/2022          Toulouse FC             OGC Nice  1:1 (1:0)
# 4                   Montpellier HSC         ESTAC Troyes  3:2 (2:2)
# 5                         Lille OSC           AJ Auxerre  4:1 (3:0)
# 6                           RC Lens    Stade Brestois 29  3:2 (1:0)
# 7                        Angers SCO            FC Nantes  0:0 (0:0)
# 8                     Stade Rennais           FC Lorient  0:1 (0:0)
# 9               Olympique Marseille       Stade de Reims  4:1 (2:0)
# 10  12/08/2022            FC Nantes            Lille OSC  1:1 (1:0)
# 11  13/08/2022            AS Monaco        Stade Rennais  1:1 (0:0)
# 12              Paris Saint-Germain      Montpellier HSC  5:2 (2:0)
# 13  14/08/2022           AC Ajaccio              RC Lens  0:0 (0:0)
# 14                       AJ Auxerre           Angers SCO  2:2 (2:1)
# 15                     ESTAC Troyes          Toulouse FC  0:3 (0:1)
# 16                   Stade de Reims     Clermont Foot 63  2:4 (2:0)
# 17                         OGC Nice        RC Strasbourg  1:1 (1:0)
# 18                Stade Brestois 29  Olympique Marseille  1:1 (0:1)
# 19  07/09/2022           FC Lorient   Olympique Lyonnais  3:1 (2:1)
#
#    League Played
# 0      2022-2023
# 1      2022-2023
# 2      2022-2023
# 3      2022-2023
# 4      2022-2023
# 5      2022-2023
# 6      2022-2023
# 7      2022-2023
# 8      2022-2023
# 9      2022-2023
# 10     2022-2023
# 11     2022-2023
# 12     2022-2023
# 13     2022-2023
# 14     2022-2023
# 15     2022-2023
# 16     2022-2023
# 17     2022-2023
# 18     2022-2023
# 19     2022-2023
# Processing league: England
#          Dates                Home Team                Away Team      Score  \
# 0   05/08/2022           Crystal Palace               Arsenal FC  0:2 (0:1)
# 1   06/08/2022                Fulham FC             Liverpool FC  2:2 (1:0)
# 2                       AFC Bournemouth              Aston Villa  2:0 (1:0)
# 3                          Leeds United  Wolverhampton Wanderers  2:1 (1:1)
# 4                      Newcastle United        Nottingham Forest  2:0 (0:0)
# 5                     Tottenham Hotspur           Southampton FC  4:1 (2:1)
# 6                            Everton FC               Chelsea FC  0:1 (0:1)
# 7   07/08/2022           Leicester City             Brentford FC  2:2 (1:0)
# 8                     Manchester United   Brighton & Hove Albion  1:2 (0:2)
# 9                       West Ham United          Manchester City  0:2 (0:1)
# 10  13/08/2022              Aston Villa               Everton FC  2:1 (1:0)
# 11               Brighton & Hove Albion         Newcastle United  0:0 (0:0)
# 12                           Arsenal FC           Leicester City  4:2 (2:0)
# 13                       Southampton FC             Leeds United  2:2 (0:0)
# 14                      Manchester City          AFC Bournemouth  4:0 (3:0)
# 15              Wolverhampton Wanderers                Fulham FC  0:0 (0:0)
# 16                         Brentford FC        Manchester United  4:0 (4:0)
# 17  14/08/2022        Nottingham Forest          West Ham United  1:0 (1:0)
# 18                           Chelsea FC        Tottenham Hotspur  2:2 (1:0)
# 19  15/08/2022             Liverpool FC           Crystal Palace  1:1 (0:1)
#
#    League Played
# 0      2022-2023
# 1      2022-2023
# 2      2022-2023
# 3      2022-2023
# 4      2022-2023
# 5      2022-2023
# 6      2022-2023
# 7      2022-2023
# 8      2022-2023
# 9      2022-2023
# 10     2022-2023
# 11     2022-2023
# 12     2022-2023
# 13     2022-2023
# 14     2022-2023
# 15     2022-2023
# 16     2022-2023
# 17     2022-2023
# 18     2022-2023
# 19     2022-2023
# Processing league: Spain
#          Dates           Home Team           Away Team      Score  \
# 0   12/08/2022          CA Osasuna          Sevilla FC  2:1 (1:1)
# 1   13/08/2022            RC Celta  Espanyol Barcelona  2:2 (1:0)
# 2                  Real Valladolid       Villarreal CF  0:3 (0:0)
# 3                     FC Barcelona      Rayo Vallecano  0:0 (0:0)
# 4   14/08/2022            Cádiz CF       Real Sociedad  0:1 (0:1)
# 5                      Valencia CF           Girona FC  1:0 (1:0)
# 6                       UD Almería         Real Madrid  1:2 (1:0)
# 7   15/08/2022       Athletic Club        RCD Mallorca  0:0 (0:0)
# 8                        Getafe CF     Atlético Madrid  0:3 (0:1)
# 9                       Real Betis            Elche CF  3:0 (2:0)
# 10  19/08/2022  Espanyol Barcelona      Rayo Vallecano  0:2 (0:1)
# 11                      Sevilla FC     Real Valladolid  1:1 (0:0)
# 12  20/08/2022          CA Osasuna            Cádiz CF  2:0 (1:0)
# 13                    RCD Mallorca          Real Betis  1:2 (0:1)
# 14                        RC Celta         Real Madrid  1:4 (1:2)
# 15  21/08/2022       Athletic Club         Valencia CF  1:0 (1:0)
# 16                 Atlético Madrid       Villarreal CF  0:2 (0:0)
# 17                   Real Sociedad        FC Barcelona  1:4 (1:1)
# 18  22/08/2022            Elche CF          UD Almería  1:1 (1:1)
# 19                       Girona FC           Getafe CF  3:1 (1:0)
#
#    League Played
# 0      2022-2023
# 1      2022-2023
# 2      2022-2023
# 3      2022-2023
# 4      2022-2023
# 5      2022-2023
# 6      2022-2023
# 7      2022-2023
# 8      2022-2023
# 9      2022-2023
# 10     2022-2023
# 11     2022-2023
# 12     2022-2023
# 13     2022-2023
# 14     2022-2023
# 15     2022-2023
# 16     2022-2023
# 17     2022-2023
# 18     2022-2023
# 19     2022-2023
# Processing league: Germany
#          Dates             Home Team             Away Team      Score  \
# 0   05/08/2022   Eintracht Frankfurt        Bayern München  1:6 (0:5)
# 1   06/08/2022    1. FC Union Berlin            Hertha BSC  3:1 (1:0)
# 2               Bor. Mönchengladbach       1899 Hoffenheim  3:1 (1:1)
# 3                      VfL Wolfsburg         Werder Bremen  2:2 (1:2)
# 4                         VfL Bochum       1. FSV Mainz 05  1:2 (1:1)
# 5                        FC Augsburg           SC Freiburg  0:4 (0:0)
# 6                  Borussia Dortmund      Bayer Leverkusen  1:0 (1:0)
# 7   07/08/2022         VfB Stuttgart            RB Leipzig  1:1 (1:1)
# 8                         1. FC Köln         FC Schalke 04  3:1 (0:0)
# 9   12/08/2022           SC Freiburg     Borussia Dortmund  1:3 (1:0)
# 10  13/08/2022      Bayer Leverkusen           FC Augsburg  1:2 (1:1)
# 11                        RB Leipzig            1. FC Köln  2:2 (1:1)
# 12                   1899 Hoffenheim            VfL Bochum  3:2 (2:2)
# 13                        Hertha BSC   Eintracht Frankfurt  1:1 (1:0)
# 14                     Werder Bremen         VfB Stuttgart  2:2 (1:1)
# 15                     FC Schalke 04  Bor. Mönchengladbach  2:2 (1:0)
# 16  14/08/2022       1. FSV Mainz 05    1. FC Union Berlin  0:0 (0:0)
# 17                    Bayern München         VfL Wolfsburg  2:0 (2:0)
# 18  19/08/2022  Bor. Mönchengladbach            Hertha BSC  1:0 (1:0)
# 19  20/08/2022     Borussia Dortmund         Werder Bremen  2:3 (1:0)
#
#    League Played
# 0      2022-2023
# 1      2022-2023
# 2      2022-2023
# 3      2022-2023
# 4      2022-2023
# 5      2022-2023
# 6      2022-2023
# 7      2022-2023
# 8      2022-2023
# 9      2022-2023
# 10     2022-2023
# 11     2022-2023
# 12     2022-2023
# 13     2022-2023
# 14     2022-2023
# 15     2022-2023
# 16     2022-2023
# 17     2022-2023
# 18     2022-2023
# 19     2022-2023
# Data collection completed. CSV files saved.
